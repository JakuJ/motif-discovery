# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
fr = np.empty((0, 7))
with open("fascia_res_mr.csv") as f:
    j = 0
    for line in f:
        if j:
            vec = line.split(";")
            
            vec[1] = vec[1][8]+"_"+vec[1][12]
            vec[6] = vec[6][0:(len(vec[6])-1)]
            fr = np.vstack((fr, vec))
        j += 1

# %%
res1 = np.empty((0, 4))
with open("resultsFilmweb2577v3136e.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        res1 = np.vstack((res1, vec))
        
res2 = np.empty((0, 4))
with open("resultsFilmweb3395v6048e.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        res2 = np.vstack((res2, vec))
        
res3 = np.empty((0, 4))
with open("resultsFilmweb3984v10288e.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        res3 = np.vstack((res3, vec))
        
res4 = np.empty((0, 4))
with open("resultsFilmweb4627v18965e.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        res4 = np.vstack((res4, vec))
        
resh = np.empty((0, 4))
with open("resultshpylo.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        resh = np.vstack((resh, vec))
        
resn = np.empty((0, 4))
with open("resultsNBA4800v146370e.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        resn = np.vstack((resn, vec))
        
ress = np.empty((0, 4))
with open("resultsScerevisiae.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        ress = np.vstack((ress, vec))
        
resc = np.empty((0, 4))
with open("resultsColi.txt") as f:
    for line in f:
        vec = line.split(" ")
        vec[3] = vec[3][0:(len(vec[3])-2)]
        date_time = datetime.datetime.strptime(vec[3], "%H:%M:%S.%f")
        a_timedelta = date_time - datetime.datetime(1900, 1, 1)
        vec[3] = seconds = a_timedelta.total_seconds()
        resc = np.vstack((resc, vec))
        
def get_names(res1):
    return np.hstack((res1, np.array(np.char.array(res1[:, 0]) +np.repeat("_", res1.shape[0]) + np.char.array(res1[:, 1])).reshape(-1, 1)))

res1 = get_names(res1)
res2 = get_names(res2)
res3 = get_names(res3)
res4 = get_names(res4)
resn = get_names(resn)
ress = get_names(ress)
resh = get_names(resh)
resc = get_names(resc)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax1.set_yscale("log")
ax1.set_ylim(0.1, 20000)
ax1.set_ylabel("")
ax1.set_xlabel("")
ax1.set_title("Small dataset - 2577 v., 3136 e.")
ax1.grid()
ax1.scatter(res1[:, 0], res1[:, 3].astype(float), s= 50)

ax2.set_yscale("log")
ax2.set_ylim(0.1, 20000)
ax2.set_ylabel("")
ax2.set_xlabel("")
ax2.set_title("Medium dataset - 3395 v., 6048 e.")
ax2.grid()
ax2.scatter(res2[:, 0], res2[:, 3].astype(float), s= 50)

ax3.set_yscale("log")
ax3.set_ylim(0.1, 20000)
ax3.set_ylabel("")
ax3.set_xlabel("")
ax3.set_title("Big dataset - 3984 v., 10288 e.")
ax3.scatter(res3[:, 0].astype(int), res3[:, 3].astype(float), s= 50)
ax3.grid()
ax3.set_xticks(ticks = [3, 4, 5, 6])

ax4.set_yscale("log")
ax4.set_ylim(0.1, 20000)
ax4.set_ylabel("")
ax4.set_xlabel("")
ax4.set_title("Large dataset - 4627 v., 18965 e.")
ax4.grid()
ax4.scatter(res4[:, 0].astype(int), res4[:, 3].astype(float), s= 50)
ax4.set_xticks(ticks = [3, 4, 5, 6])

fig.text(0.5, 0.04, 'Number of vertices of a subgraph', ha='center', fontsize = 15)
fig.text(0.04, 0.5, 'Seconds', va='center', rotation='vertical', fontsize = 15)
fig.suptitle("Calculation time of GK algorithm on Filmweb dataset samples", fontsize = 20)

plt.savefig("resultsFilmwebMotif.png")

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

legend_elements = [Line2D([0], [0], marker='o', color='white', label='Star-like graph',
                          markerfacecolor='red', markersize=15),
                  Line2D([0], [0], marker='o', color='white', label='Other graph',
                          markerfacecolor='#1f77b4', markersize=15)]


ax1.set_ylabel("")
ax1.set_xlabel("")
ax1.set_title("Small dataset - 2577 v., 3136 e.")
ax1.grid()
c = np.repeat("#1f77b4", res1.shape[0])
c[res1[:, 1] == "0"] = "red"
ax1.legend(handles=legend_elements)
ax1.scatter(res1[:, 2].astype(int), res1[:, 3].astype(float), s= 50, c = c)



ax2.set_ylabel("")
ax2.set_xlabel("")
ax2.set_title("Medium dataset - 3395 v., 6048 e.")
ax2.grid()
c = np.repeat("#1f77b4", res2.shape[0])
c[res2[:, 1] == "0"] = "red"
ax2.legend(handles=legend_elements)
ax2.scatter(res2[:, 2].astype(int), res2[:, 3].astype(float), s= 50, c = c)


ax3.set_ylabel("")
ax3.set_xlabel("")
ax3.set_title("Big dataset - 3984 v., 10288 e.")
c = np.repeat("#1f77b4", res3.shape[0])
c[res3[:, 1] == "0"] = "red"
ax3.legend(handles=legend_elements)
ax3.scatter(res3[:, 2].astype(int), res3[:, 3].astype(float), s= 50, c = c)
ax3.grid()


ax4.set_ylabel("")
ax4.set_xlabel("")
ax4.set_title("Large dataset - 4627 v., 18965 e.")
ax4.grid()
c = np.repeat("#1f77b4", res4.shape[0])
ax4.legend(handles=legend_elements)
c[res4[:, 1] == "0"] = "red"
ax4.scatter(res4[:, 2].astype(int), res4[:, 3].astype(float), s= 50, c = c)


fig.text(0.5, 0.04, 'Number of calculated appearances of subgraphs', ha='center', fontsize = 15)
fig.text(0.04, 0.5, 'Seconds', va='center', rotation='vertical', fontsize = 15)
fig.suptitle("Calculation time of GK algorithm on Filmweb dataset samples", fontsize = 20)

from matplotlib.patches import Patch
from matplotlib.lines import Line2D


plt.savefig("resultsFilmwebNumber.png")

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 12

fig = plt.figure()
ax1 = fig.add_subplot(3, 1, 1)
ax2 = fig.add_subplot(3, 1, 2)
ax3 = fig.add_subplot(3, 1, 3)

ax1.set_yscale("log")
ax1.set_ylim(0.1, 20000)
ax1.set_ylabel("")
ax1.set_xlabel("")
ax1.set_title("H.pylori dataset - 714 v., 1121 e.")
ax1.grid()
ax1.scatter(resh[:, 0], resh[:, 3].astype(float), s= 50)

ax2.set_yscale("log")
ax2.set_ylim(0.1, 20000)
ax2.set_ylabel("")
ax2.set_xlabel("")
ax2.set_title("S.cerevisciae dataset - 690 v., 1093 e.")
ax2.grid()
ax2.scatter(ress[:, 0], ress[:, 3].astype(float), s= 50)

ax3.set_yscale("log")
ax3.set_ylim(0.1, 20000)
ax3.set_ylabel("")
ax3.set_xlabel("")
ax3.set_title("E.coli dataset - 423 v., 578 e.")
ax3.grid()
ax3.scatter(resc[:, 0].astype(int), resc[:, 3].astype(float), s= 50)
ax3.set_xticks(ticks = [3, 4, 5, 6])

fig.text(0.5, 0.04, 'Number of vertices of a subgraph', ha='center', fontsize = 15)
fig.text(0.04, 0.5, 'Seconds', va='center', rotation='vertical', fontsize = 15)
fig.suptitle("Calculation time of GK algorithm on biological datasets samples", fontsize = 20)

plt.savefig("resultsBioMotif.png")

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 12

fig = plt.figure()
ax1 = fig.add_subplot(3, 1, 1)
ax2 = fig.add_subplot(3, 1, 2)
ax3 = fig.add_subplot(3, 1, 3)

legend_elements = [Line2D([0], [0], marker='o', color='white', label='Star-like graph',
                          markerfacecolor='red', markersize=15),
                  Line2D([0], [0], marker='o', color='white', label='Other graph',
                          markerfacecolor='#1f77b4', markersize=15)]


ax1.set_ylabel("")
ax1.set_xlabel("")
ax1.set_title("H.pylori dataset - 714 v., 1121 e.")
ax1.grid()
c = np.repeat("#1f77b4", resh.shape[0])
c[resh[:, 1] == "0"] = "red"
ax1.legend(handles=legend_elements)
ax1.scatter(resh[:, 2].astype(int), resh[:, 3].astype(float), s= 50, c = c)



ax2.set_ylabel("")
ax2.set_xlabel("")
ax2.set_title("S.cerevisciae dataset - 690 v., 1093 e.")
ax2.grid()
c = np.repeat("#1f77b4", ress.shape[0])
c[ress[:, 1] == "0"] = "red"
ax2.legend(handles=legend_elements)
ax2.scatter(ress[:, 2].astype(int), ress[:, 3].astype(float), s= 50, c = c)


ax3.set_ylabel("")
ax3.set_xlabel("")
ax3.set_title("E.coli dataset - 423 v., 578 e.")
ax3.grid()
c = np.repeat("#1f77b4", resc.shape[0])
c[resc[:, 1] == "0"] = "red"
ax3.legend(handles=legend_elements)
ax3.scatter(resc[:, 2].astype(int), resc[:, 3].astype(float), s= 50, c = c)


fig.text(0.5, 0.04, 'Number of calculated appearances of subgraphs', ha='center', fontsize = 15)
fig.text(0.04, 0.5, 'Seconds', va='center', rotation='vertical', fontsize = 15)
fig.suptitle("Calculation time of GK algorithm on biological dataset samples", fontsize = 20)



plt.savefig("resultsBioNumber.png")

# %%
means1 = np.genfromtxt("filmweb5k_means.csv", delimiter=";")

# %%
names = ["3_0", "4_0", "4_1", "5_0", "5_1", "5_2", "6_0", "6_1", "6_2", "6_3", "6_4", "6_5", "6_6"]

# %%
means1 = np.empty((0, 2))
with open("filmweb5k_means.csv") as f:
    j = 0
    for line in f:
        if j != 0:
            vec = line.split(";")
            mean = float(vec[1][0:(len(vec[1])-2)])
            mean = round(mean)
            means1 = np.vstack((means1, [names[j-1], mean]))
        j += 1
        
means2 = np.empty((0, 2))
with open("filmweb10k_means.csv") as f:
    j = 0
    for line in f:
        if j != 0:
            vec = line.split(";")
            mean = float(vec[1][0:(len(vec[1])-2)])
            mean = round(mean)
            means2 = np.vstack((means2, [names[j-1], mean]))
        j += 1

means3 = np.empty((0, 2))
with open("filmweb15k_means.csv") as f:
    j = 0
    for line in f:
        if j != 0:
            vec = line.split(";")
            mean = float(vec[1][0:(len(vec[1])-2)])
            mean = round(mean)
            means3 = np.vstack((means3, [names[j-1], mean]))
        j += 1
        
means4 = np.empty((0, 2))
with open("filmweb20k_means.csv") as f:
    j = 0
    for line in f:
        if j != 0:
            vec = line.split(";")
            mean = float(vec[1][0:(len(vec[1])-2)])
            mean = round(mean)
            means4 = np.vstack((means4, [names[j-1], mean]))
        j += 1
        
meansh = np.empty((0, 2))
with open("hpylo-nonmulti_means.csv") as f:
    j = 0
    for line in f:
        if j != 0:
            vec = line.split(";")
            mean = float(vec[1][0:(len(vec[1])-2)])
            mean = round(mean)
            meansh = np.vstack((meansh, [names[j-1], mean]))
        j += 1
        
meanss = np.empty((0, 2))
with open("Scerevisiae_means.csv") as f:
    j = 0
    for line in f:
        if j != 0:
            vec = line.split(";")
            mean = float(vec[1][0:(len(vec[1])-2)])
            mean = round(mean)
            meanss = np.vstack((meanss, [names[j-1], mean]))
        j += 1

meansc = np.empty((0, 2))
with open("ecoli.csv") as f:
    j = 0
    for line in f:
        if j != 0:
            vec = line.split(";")
            mean = float(vec[1][0:(len(vec[1])-2)])
            mean = round(mean)
            meansc = np.vstack((meansc, [names[j-1], mean]))
        j += 1

# %%
frc = np.empty((0, 7))
with open("mr_coli.csv") as f:
    j = 0
    for line in f:
        if j:
            vec = line.split(";")
            
            vec[1] = vec[1][8]+"_"+vec[1][12]
            vec[6] = vec[6][0:(len(vec[6])-1)]
            frc = np.vstack((frc, vec))
        j += 1

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)



ax1.set_ylabel("")
ax1.set_xlabel("")
ax1.set_title("Small dataset - 2577 v., 3136 e.")
ax1.grid()
ax1.set_yscale("log")
ax1.set_ylim(1e3, 1e7)
c = np.repeat("#1f77b4", res1.shape[0])
c[res1[:, 1] == "0"] = "red"
temp = fr[fr[:, 0] == "filmweb5k", :]

ax1.scatter(res1[:, 4], res1[:, 2].astype(int), s = 120, alpha = 0.8, label = "GK algorithm")
ax1.scatter(means1[:, 0], means1[:, 1].astype(int), s = 120, alpha = 0.8, label = "Random network mean")
ax1.scatter(temp[:, 1], temp[:, 4].astype(float), s = 120, alpha = 0.8, label = "FASCIA")
ax1.legend()

ax2.set_ylabel("")
ax2.set_xlabel("")
ax2.set_yscale("log")
ax2.set_ylim(1e4, 1e8)
ax2.set_title("Medium dataset - 3395 v., 6048 e.")
ax2.grid()
c = np.repeat("#1f77b4", res2.shape[0])
#c[res2[:, 1] == "0"] = "red"
temp = fr[fr[:, 0] == "filmweb10k", :]
ax2.scatter(res2[:, 4], res2[:, 2].astype(int), s = 120, alpha = 0.8, label = "GK algorithm")
ax2.scatter(means2[:, 0], means2[:, 1].astype(int), s = 120, alpha = 0.8, label = "Random network mean")
ax2.scatter(temp[:, 1], temp[:, 4].astype(float), s = 120, alpha = 0.8, label = "FASCIA")
ax2.legend()


ax3.set_ylabel("")
ax3.set_xlabel("")
ax3.set_title("Big dataset - 3984 v., 10288 e.")
c = np.repeat("#1f77b4", res3.shape[0])
c[res3[:, 1] == "0"] = "red"
ax3.grid()
ax3.set_yscale("log")
ax3.set_ylim(1e3, 1e9)
temp = fr[fr[:, 0] == "filmweb15k", :]
ax3.scatter(res3[:, 4], res3[:, 2].astype(int), s = 120, alpha = 0.8, label = "GK algorithm")
ax3.scatter(means3[:, 0], means3[:, 1].astype(int), s = 120, alpha = 0.8, label = "Random network mean")
ax3.scatter(temp[:, 1], temp[:, 4].astype(float), s = 120, alpha = 0.8, label = "FASCIA")
ax3.legend()

ax4.set_ylabel("")
ax4.set_xlabel("")
ax4.set_title("Large dataset - 4627 v., 18965 e.")
ax4.grid()
c = np.repeat("#1f77b4", res4.shape[0])
ax4.set_yscale("log")
ax4.set_ylim(1e4, 1e10)
temp = fr[fr[:, 0] == "filmweb20k", :]
ax4.scatter(res4[:, 4], res4[:, 2].astype(int), s = 120, alpha = 0.8, label = "GK algorithm")
ax4.scatter(means4[:, 0], means4[:, 1].astype(float), s = 100, alpha = 0.8, label = "Random network mean")
ax4.scatter(temp[:, 1], temp[:, 4].astype(float), s = 120, alpha = 0.8, label = "FASCIA")
ax4.legend()

fig.text(0.5, 0.04, 'Tree index with the first number being number of vertices', ha='center', fontsize = 15)
fig.text(0.04, 0.5, 'Number of occurences', va='center', rotation='vertical', fontsize = 15)
fig.suptitle("Results on all trees having at most 6 vertices of GK, FASCIA \n and random network mean on Filmweb dataset", fontsize = 20)
plt.savefig("resultsv1.png")
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 13, 15

fig = plt.figure()
ax1 = fig.add_subplot(3, 1, 1)
ax2 = fig.add_subplot(3, 1, 2)
ax3 = fig.add_subplot(3, 1, 3)




ax1.set_ylabel("")
ax1.set_xlabel("")
ax1.set_title("H.pylori dataset - 714 v., 1121 e.")
ax1.grid()
ax1.set_yscale("log")
ax1.set_ylim(1e3, 1e7)


temp = fr[fr[:, 0] == "hpylo-nonmulti", :]
ax1.scatter(resh[:, 4], resh[:, 2].astype(int), s = 120, label = "GK algorithm")
ax1.scatter(meansh[:, 0], meansh[:, 1].astype(int), s = 70, label = "Random network mean")
ax1.scatter(temp[:, 1], temp[:, 4].astype(float), s = 120, alpha = 0.8, label = "FASCIA")
ax1.legend()

ax2.set_ylabel("")
ax2.set_xlabel("")
ax2.set_yscale("log")
ax2.set_ylim(1e3, 1e8)
ax2.set_title("S.cerevisciae dataset - 690 v., 1093 e.")
ax2.grid()

temp = fr[fr[:, 0] ==  "Scerevisiae_new", :]
ax2.scatter(ress[:, 4], ress[:, 2].astype(int), s = 120, label = "GK algorithm")
ax2.scatter(meanss[:, 0], meanss[:, 1].astype(int), s = 70, label = "Random network mean")
ax2.scatter(temp[:, 1], temp[:, 4].astype(float), s = 120, alpha = 0.8, label = "FASCIA")
ax2.legend()

ax3.set_ylabel("")
ax3.set_xlabel("")
ax3.set_yscale("log")
ax3.set_ylim(1e3, 1e8)
ax3.set_title("E.coli dataset - 423 v., 578 e.")
ax3.grid()

temp = frc
ax3.scatter(resc[:, 4], resc[:, 2].astype(int), s = 120, label = "GK algorithm")
ax3.scatter(meansc[:, 0], meansc[:, 1].astype(int), s = 70, label = "Random network mean")
ax3.scatter(temp[:, 1], temp[:, 4].astype(float), s = 120, alpha = 0.8, label = "FASCIA")
ax3.legend()



fig.text(0.5, 0.04, 'Tree index with the first number being number of vertices', ha='center', fontsize = 15)
fig.text(0.04, 0.5, 'Number of occurences', va='center', rotation='vertical', fontsize = 15)
fig.suptitle("Results on all trees having at most 6 vertices of GK, FASCIA \n and random network mean on biological datasets", fontsize = 20)
plt.savefig("resultsbiov1.png")
plt.show()

# %%
fr = np.empty((0, 7))
with open("fascia_res_mr.csv") as f:
    j = 0
    for line in f:
        if j:
            vec = line.split(";")
            
            vec[1] = vec[1][8]+"_"+vec[1][12]
            vec[6] = vec[6][0:(len(vec[6])-1)]
            fr = np.vstack((fr, vec))
        j += 1

# %%
#hpylo
isMotif = resh[:, 2].astype(int) > 1.01* meansh[:, 1].astype(int)
temp = fr[fr[:, 0] == "hpylo-nonmulti", :]
cols1 = [None] * len(isMotif)
for i in range(temp.shape[0]):
    if temp[i, 5].astype(int) == 0:
        cols1[i] = "#e8e81c"
    elif (temp[i, 5].astype(int) == -1 and not isMotif[i]) or (temp[i, 5].astype(int) == 1 and isMotif[i]):
        cols1[i] = "#32a852"
    else:
        cols1[i] = "#a84432"
        
isMotif = ress[:, 2].astype(int) > 1.01* meanss[:, 1].astype(int)
print(isMotif)
temp = fr[fr[:, 0] == "Scerevisiae_new", :]
cols2 = [None] * len(isMotif)
for i in range(temp.shape[0]):
    if temp[i, 5].astype(int) == 0:
        cols2[i] = "#e8e81c"
    elif (temp[i, 5].astype(int) == -1 and not isMotif[i]) or (temp[i, 5].astype(int) == 1 and isMotif[i]):
        cols2[i] = "#32a852"
    else:
        cols2[i] = "#a84432"
        
isMotif = resc[:, 2].astype(int) > 1.01* meansc[:6, 1].astype(int)
temp = frc
cols3 = [None] * len(isMotif)
for i in range(6):
    if temp[i, 5].astype(int) == 0:
        cols3[i] = "#e8e81c"
    elif (temp[i, 5].astype(int) == -1 and not isMotif[i]) or (temp[i, 5].astype(int) == 1 and isMotif[i]):
        cols3[i] = "#32a852"
    else:
        cols3[i] = "#a84432"
# Out:
# [False False False False False False False False False False False False]

# %%
timediff = resh[:, 3].astype(float) - fr[fr[:, 0] == "hpylo-nonmulti", :][:, 6].astype(float)

# %%
timediff1 = ress[:, 3].astype(float) - fr[fr[:, 0] == "Scerevisiae_new", :][:, 6].astype(float)

# %%
timediff2 = resc[:, 3].astype(float) - frc[:6, 6].astype(float)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 13

fig = plt.figure()
ax1 = fig.add_subplot(3, 2, 1)
ax2 = fig.add_subplot(3, 2, 2)
ax3 = fig.add_subplot(3, 2, 3)
ax4 = fig.add_subplot(3, 2, 4)
ax5 = fig.add_subplot(3, 2, 5)
ax6 = fig.add_subplot(3, 2, 6)

custom_lines = [Line2D([0], [0], color="#32a852", lw=4),
                Line2D([0], [0], color="#e8e81c", lw=4),
                Line2D([0], [0], color="#a84432", lw=4)]

ax1.set_title("H.pylori dataset - 714 v., 1121 e.")
ax1.bar(resh[:3, 4], timediff[:3], color = cols1[:3])
ax1.set_ylim(-3, 6)

ax2.set_title("H.pylori dataset - 714 v., 1121 e.")
ax2.bar(resh[3:, 4], timediff[3:], color = cols1[3:])
ax2.set_ylim(0.1, 10000)
ax2.set_yscale("log")

ax3.set_title("S.cerevisciae dataset - 690 v., 1093 e.")
ax3.bar(ress[:3, 4], timediff1[:3], color = cols2[:3])
ax3.set_ylim(-3, 6)


ax4.set_title("S.cerevisciae dataset - 690 v., 1093 e.")
ax4.bar(ress[3:, 4], timediff1[3:], color = cols2[3:])
ax4.set_ylim(0.1, 100000)
ax4.legend(custom_lines, ['Right decision', 'No decision', 'Wrong decision'])
ax4.set_yscale("log")

ax5.set_title("E.coli dataset - 423 v., 578 e.")
ax5.bar(resc[:3, 4], timediff2[:3], color = cols2[:3])
ax5.set_ylim(-3, 6)


ax6.set_title("E.coli dataset - 423 v., 578 e.")
ax6.bar(resc[3:, 4], timediff2[3:], color = cols3[3:])
ax6.set_ylim(0.1, 100000)
ax6.legend(custom_lines, ['Right decision', 'No decision', 'Wrong decision'])
ax6.set_yscale("log")

fig.text(0.5, 0.04, 'Indices of trees', ha='center', fontsize = 15)
fig.text(0.04, 0.5, 'Seconds', va='center', rotation='vertical', fontsize = 15)
fig.suptitle("Time difference between GK and FASCIA algorithms", fontsize = 20)
plt.savefig("resultsTime.png")
plt.show()
